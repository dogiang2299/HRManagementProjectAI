# %%
import pandas as pd

input_path = "/Users/nguyenduykhanh/Documents/GraduationProject/Recommendation_Project/recommendation/notebook/Embedding/data_outputs/15_top5_recommendations_for_ui.xlsx"
output_path = "/Users/nguyenduykhanh/Documents/GraduationProject/Recommendation_Project/backend/uploads/ai/15_top5_recommendations_for_ui.json"

df = pd.read_excel(input_path)
df.to_json(output_path, orient="records", force_ascii=False, indent=2)

print("Done:", output_path)
print(df.head())
# Out:
# Done: /Users/nguyenduykhanh/Documents/GraduationProject/Recommendation_Project/backend/uploads/ai/15_top5_recommendations_for_ui.json
#   candidate_id job_id            job_title  hybrid_score  hybrid_rank  \
# 0         C001   J001    Backend Developer      0.983540            1
# 1         C001   J003  Fullstack Developer      0.612240            2
# 2         C001   J002   Frontend Developer      0.611709            3
# 3         C001   J008     Business Analyst      0.607755            4
# 4         C001   J004         Data Analyst      0.606846            5
#
#    semantic_similarity  skill_overlap_score  group_similarity_score  \
# 0             0.917700                  1.0                       1
# 1             0.861202                  0.0                       1
# 2             0.858543                  0.0                       1
# 3             0.838776                  0.0                       1
# 4             0.834230                  0.0                       1
#
# ...
